# %%
import random

# Generate list of random values
ls = [random.randint(1,100) for x in range(10)]

# %%
print(f"{ls} -> Original List \n")

def insertion_sort(ls):
    """
    A function that utilizes the insertion sort algorithm to sort a unsorted list

    ls = unsorted list object of numerical values
    """

    # Sorted values counter
    already_sorted = 1

    # Loop over list
    for x in range(len(ls)):

        print(f"------Interval: {x}------")
        print(f"List before sort:\n{ls}\n")

        # Dont change first element in list
        if x == 0:
            print(f"List after sort:\n{ls}\n")
            continue

        # Hold the number being compared
        temp = ls.pop(x)

        # Loop over rest of list and break loop once conditional is met
        for y in range(already_sorted+1):

            # Insert temp at end of sorted list half if at end fo index and temp is greater than ls[x] 
            if ((y == already_sorted) & (temp >= ls[y-1])):
                ls.insert(y, temp)
                break
            
            # If temp is <= then insert at x
            elif temp <= ls[y]:
                ls.insert(y,temp)
                break
            
            # If  temp is greater then continue
            elif temp >= ls[y]:
                continue
        
        # Increment sorted counter
        already_sorted+=1

        print(f"List after sort:\n{ls}\n")

    return ls

print(f"{insertion_sort(ls)} -> Sorted List")
# Out:
# [27, 40, 49, 33, 76, 66, 22, 55, 27, 57] -> Original List
#
# ------Interval: 0------
# List before sort:
# [27, 40, 49, 33, 76, 66, 22, 55, 27, 57]
#
# List after sort:
# [27, 40, 49, 33, 76, 66, 22, 55, 27, 57]
#
# ------Interval: 1------
# List before sort:
# [27, 40, 49, 33, 76, 66, 22, 55, 27, 57]
#
# List after sort:
# [27, 40, 49, 33, 76, 66, 22, 55, 27, 57]
#
# ------Interval: 2------
# List before sort:
# [27, 40, 49, 33, 76, 66, 22, 55, 27, 57]
#
# List after sort:
# [27, 40, 49, 33, 76, 66, 22, 55, 27, 57]
#
# ------Interval: 3------
# List before sort:
# [27, 40, 49, 33, 76, 66, 22, 55, 27, 57]
#
# List after sort:
# [27, 33, 40, 49, 76, 66, 22, 55, 27, 57]
#
# ------Interval: 4------
# List before sort:
# [27, 33, 40, 49, 76, 66, 22, 55, 27, 57]
#
# List after sort:
# [27, 33, 40, 49, 76, 66, 22, 55, 27, 57]
#
# ------Interval: 5------
# List before sort:
# [27, 33, 40, 49, 76, 66, 22, 55, 27, 57]
#
# List after sort:
# [27, 33, 40, 49, 66, 76, 22, 55, 27, 57]
#
# ------Interval: 6------
# List before sort:
# [27, 33, 40, 49, 66, 76, 22, 55, 27, 57]
#
# List after sort:
# [22, 27, 33, 40, 49, 66, 76, 55, 27, 57]
#
# ------Interval: 7------
# List before sort:
# [22, 27, 33, 40, 49, 66, 76, 55, 27, 57]
#
# List after sort:
# [22, 27, 33, 40, 49, 55, 66, 76, 27, 57]
#
# ------Interval: 8------
# List before sort:
# [22, 27, 33, 40, 49, 55, 66, 76, 27, 57]
#
# List after sort:
# [22, 27, 27, 33, 40, 49, 55, 66, 76, 57]
#
# ------Interval: 9------
# List before sort:
# [22, 27, 27, 33, 40, 49, 55, 66, 76, 57]
#
# List after sort:
# [22, 27, 27, 33, 40, 49, 55, 57, 66, 76]
#
# [22, 27, 27, 33, 40, 49, 55, 57, 66, 76] -> Sorted List
